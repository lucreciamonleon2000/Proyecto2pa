# %%
import fotoapp

# 1. Cargar imagen
fotoapp.leer_imagen("/content/drive/MyDrive/Tecnicatura Tecnologia de Programación/Segundo Cuatrimestre/Python Avanzada/Proyecto 2/Proyecto 2/casamiento.jpeg")

# 2. Mostrar original
fotoapp.mostrar_original()

# 3. Ecualizar contraste
fotoapp.ecualizar_contraste()

# 4. Aplicar desenfoque
fotoapp.desenfoque()

# 5. Detectar bordes
fotoapp.detectar_bordes()
